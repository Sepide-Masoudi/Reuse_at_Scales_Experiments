# %%
# %matplotlib inline
import pandas as pd
from sma import Config, Report

# %%
config = Config.from_file("./sma-measurments.yaml")

reports = Report.load_from_config(config)

# %%
reports[0]['wall_power']
# Out:
#                                                 __name__  \
# timestamp
# 2025-11-21 13:56:44.595000029+00:00  shelly_apower_watts
# 2025-11-21 13:56:44.595000029+00:00  shelly_apower_watts
# 2025-11-21 13:56:44.595000029+00:00  shelly_apower_watts
# 2025-11-21 13:56:44.595000029+00:00  shelly_apower_watts
#
#                                               exported_instance  \
# timestamp
# 2025-11-21 13:56:44.595000029+00:00  shellyplugsg3-e4b063d850bc
# 2025-11-21 13:56:44.595000029+00:00  shellyplugsg3-e4b063dcdf60
# 2025-11-21 13:56:44.595000029+00:00  shellyplugsg3-e4b063de2610
# 2025-11-21 13:56:44.595000029+00:00  shellyplugsg3-e4b063e44044
#
#                                                              instance     job  \
# timestamp
# 2025-11-21 13:56:44.595000029+00:00  ise-energy.ise.tu-berlin.de:9110  shelly
# 2025-11-21 13:56:44.595000029+00:00  ise-energy.ise.tu-berlin.de:9110  shelly
# 2025-11-21 13:56:44.595000029+00:00  ise-energy.ise.tu-berlin.de:9110  shelly
# ...
